# %% [markdown]
# <p style="color: #000000; font-size: 16px; text-align: right; margin-bottom: 20px;"> María Carolina González Bernal
# </p>
# <p style="color: #000000; font-size: 16px; text-align: right; margin-bottom: 20px;"> Python básico I
# </p>
# <p style="color: #000000; font-size: 28px; font-weight: bold; text-align: center; margin-top: 20px;">  Mi primer programa
# </p>

# %% [markdown]
# ___

# %% [markdown]
# ## Ejercicio 1
# Crea 2 variables, Variable1 con valor numérico=5 y Variable2 con valor texto= "Hola"

# %%
# Variable númerica (int)
Variable1 = 5
# Variable de texto (str)
Variable2 = "Hola"

print(f"Valor de las variables: {Variable1} y {Variable2}.")
# Out:
# Valor de las variables: 5 y Hola.

# %% [markdown]
# ## Ejercicio 2
# Crea 2 variables, Variable1 y Variable2 que reciben valor por teclado. Después muestra su multiplicación

# %%
# Valores de 'User input'
Variable1 = input()
Variable2 = input()
# Convertir a int, mutiplicación e impresión 
print(int(Variable1) * int(Variable2))

# %% [markdown]
# ## Ejercicio 3
# Pide tu nombre por teclado y muestra un mensaje personalizado deseandote un buen día

# %%
print('Nombre:')
nombre= input()
print(f"¡Hola, {nombre}! Espero que tengas un buen día")

# %% [markdown]
# ## Ejercicio 4
# Pide 3 variables: Variable1, Variable2 y Variable3. Introduce en ellas por teclado valores numéricos. Si son iguales mostrara True, False en caso contrario. (Todavía no podemos usar IF)

# %%
# Valores de 'User input'
# Uso de int() para convertirlo en un entero
Variable1 = int(input()) 
Variable2 = int(input())
Variable3 = int(input())

# Se usa '==' para buscar igualdades, devolverá 'True' o 'False'
(Variable1==Variable2) and (Variable2 ==Variable3)

# %% [markdown]
# ## Ejercicio 5
# Pide 3 variables: Variable1, Variable2 y Variable3. Introduce en ellas por teclado valores numéricos. Si alguna es mayor de 100 mostrara True, False en caso contrario. (Todavía no podemos usar IF)

# %%
# Valores de 'User input'
# Uso de int() para convertirlo en un entero
Variable1 = int(input()) 
Variable2 = int(input())
Variable3 = int(input()) 

# Se usa '>' para indicar mayor que
# Se usa 'or' para realizar la búsqueda de la condición en las variables,
# si encuencuentra una verdadera devolverá 'True', sino 'False'
(Variable1 > 100) or (Variable2 > 100) or (Variable3 > 100)
